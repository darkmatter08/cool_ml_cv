# %%
import numpy as np
import matplotlib.pyplot as plt
import sklearn
import csv
plt.rcParams['figure.figsize'] = [10, 7]

# %%
import pandas as pd

# %% [markdown]
# Load up the data as a numpy array

# %%
test = pd.read_csv('/Users/jains/Downloads/Neural-Network-with-Keras-for-Kaggle-Titanic-Dataset-master/data/test.csv')
train = pd.read_csv('/Users/jains/Downloads/Neural-Network-with-Keras-for-Kaggle-Titanic-Dataset-master/data/train.csv')

# %%
test
# Out:
#      PassengerId  Pclass                                               Name  \
# 0            892       3                                   Kelly, Mr. James
# 1            893       3                   Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                          Myles, Mr. Thomas Francis
# 3            895       3                                   Wirz, Mr. Albert
# 4            896       3       Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# 5            897       3                         Svensson, Mr. Johan Cervin
# 6            898       3                               Connolly, Miss. Kate
# 7            899       2                       Caldwell, Mr. Albert Francis
# 8            900       3          Abrahim, Mrs. Joseph (Sophie Halaut Easu)
# 9            901       3                            Davies, Mr. John Samuel
# 10           902       3                                   Ilieff, Mr. Ylio
# ...

# %%
train
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %%
test.dtypes
# Out:
# PassengerId      int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
dtype = [
    ('PassengerId', np.int64),
    ('Pclass', np.int64),
    ('Name', np.object_),
    ('Sex', np.object_),
    ('Age', np.float64),
    ('SibSp', np.int64),
    ('Parch', np.int64),
    ('Ticket', np.object_),
    ('Fare', np.float64),
    ('Cabin', np.object_),
    ('Embarked', np.object_),
]

# %%
test.shape
# Out:
# (418, 11)

# %%
a = np.empty(test.shape[0], dtype=dtype)

# %%
for r in test:
    a[r] = test[r]

# %%
a
# Out:
# array([( 892, 3, 'Kelly, Mr. James', 'male', 34.5 , 0, 0, '330911',   7.8292, nan, 'Q'),
#        ( 893, 3, 'Wilkes, Mrs. James (Ellen Needs)', 'female', 47.  , 1, 0, '363272',   7.    , nan, 'S'),
#        ( 894, 2, 'Myles, Mr. Thomas Francis', 'male', 62.  , 0, 0, '240276',   9.6875, nan, 'Q'),
#        ( 895, 3, 'Wirz, Mr. Albert', 'male', 27.  , 0, 0, '315154',   8.6625, nan, 'S'),
#        ( 896, 3, 'Hirvonen, Mrs. Alexander (Helga E Lindqvist)', 'female', 22.  , 1, 1, '3101298',  12.2875, nan, 'S'),
#        ( 897, 3, 'Svensson, Mr. Johan Cervin', 'male', 14.  , 0, 0, '7538',   9.225 , nan, 'S'),
#        ( 898, 3, 'Connolly, Miss. Kate', 'female', 30.  , 0, 0, '330972',   7.6292, nan, 'Q'),
#        ( 899, 2, 'Caldwell, Mr. Albert Francis', 'male', 26.  , 1, 1, '248738',  29.    , nan, 'S'),
#        ( 900, 3, 'Abrahim, Mrs. Joseph (Sophie Halaut Easu)', 'female', 18.  , 0, 0, '2657',   7.2292, nan, 'C'),
# ...

# %% [markdown]
# Explore the data

# %%
for col in a.dtype.names:
    if np.count_nonzero(a[col] == np.nan):
        print col

# %%
nanexample = a[a['PassengerId'] == 924]
nanexample
# Out:
# array([(924, 3, 'Dean, Mrs. Bertram (Eva Georgetta Light)', 'female', 33., 1, 2, 'C.A. 2315', 20.575, nan, 'S')],
#       dtype=[('PassengerId', '<i8'), ('Pclass', '<i8'), ('Name', 'O'), ('Sex', 'O'), ('Age', '<f8'), ('SibSp', '<i8'), ('Parch', '<i8'), ('Ticket', 'O'), ('Fare', '<f8'), ('Cabin', 'O'), ('Embarked', 'O')])

# %%
np.isnan(nanexample['Cabin'][0])
# Out:
# True
